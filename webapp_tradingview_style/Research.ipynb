# %%
#  You now have a browser app with TradingView‑style chart, volume, EMAs, crosshair, and zoom/pan via lightweight‑charts
uvicorn app
CMD: .main_fastapi:app --reload
